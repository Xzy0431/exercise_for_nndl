# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                # in_channels=      ,  
                # out_channels=     ,
                # kernel_size=      ,
                # stride=           ,
                # padding=          ,

                # 输入通道为1，输出通道为32，卷积核大小为7x7，步幅为1，填充方式为same
                in_channels=1,  # 输入为灰度图像，通道数为1
                out_channels=32,  # 输出32个特征图
                kernel_size=7,  # 卷积核大小7x7
                stride=1,  # 步幅为1
                padding=3,  # 填充方式为'SAME'，保持输出大小相同
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.

            nn.Conv2d(  # 输入32个通道，输出64个通道，卷积核大小为5x5，步幅为1，填充方式为same
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),  # 激活函数ReLU
            nn.MaxPool2d(2),  # 2x2最大池化
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view( -1, 7 * 7 * 64 )  # 展平操作，大小调整为(batch_size, 7*7*64)
        # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████████████████████████████████████████████████| 9912422/9912422 [00:09<00:00, 1064095.25it/s]
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|███████████████████████████████████████████████████████████| 28881/28881 [00:00<00:00, 101702.40it/s]
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|███████████████████████████████████████████████████████| 1648877/1648877 [00:02<00:00, 723252.48it/s]
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|████████████████████████████████████████████████████████████| 4542/4542 [00:00<00:00, 4540164.15it/s]
# C:\Users\yier0431\tools\anaconda\anaconda3\envs\nndlHW\lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\yier0431\AppData\Local\Temp\ipykernel_24048\291536206.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# C:\Users\yier0431\tools\anaconda\anaconda3\envs\nndlHW\lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\yier0431\AppData\Local\Temp\ipykernel_24048\291536206.py:81: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# ========== 20 ===== ===== test accuracy is  0.216 ==========
# ========== 40 ===== ===== test accuracy is  0.354 ==========
# ========== 60 ===== ===== test accuracy is  0.502 ==========
# ========== 80 ===== ===== test accuracy is  0.582 ==========
# ========== 100 ===== ===== test accuracy is  0.622 ==========
# ========== 120 ===== ===== test accuracy is  0.638 ==========
# ========== 140 ===== ===== test accuracy is  0.68 ==========
# ========== 160 ===== ===== test accuracy is  0.722 ==========
# ========== 180 ===== ===== test accuracy is  0.764 ==========
# ========== 200 ===== ===== test accuracy is  0.786 ==========
# ========== 220 ===== ===== test accuracy is  0.822 ==========
# ========== 240 ===== ===== test accuracy is  0.834 ==========
# ========== 260 ===== ===== test accuracy is  0.84 ==========
# ========== 280 ===== ===== test accuracy is  0.836 ==========
# ========== 300 ===== ===== test accuracy is  0.842 ==========
# ========== 320 ===== ===== test accuracy is  0.866 ==========
# ========== 340 ===== ===== test accuracy is  0.856 ==========
# ========== 360 ===== ===== test accuracy is  0.866 ==========
# ========== 380 ===== ===== test accuracy is  0.882 ==========
# ========== 400 ===== ===== test accuracy is  0.898 ==========
# ========== 420 ===== ===== test accuracy is  0.894 ==========
# ========== 440 ===== ===== test accuracy is  0.898 ==========
# ========== 460 ===== ===== test accuracy is  0.896 ==========
# ========== 480 ===== ===== test accuracy is  0.888 ==========
# ========== 500 ===== ===== test accuracy is  0.896 ==========
# ========== 520 ===== ===== test accuracy is  0.892 ==========
# ========== 540 ===== ===== test accuracy is  0.89 ==========
# ========== 560 ===== ===== test accuracy is  0.908 ==========
# ========== 580 ===== ===== test accuracy is  0.914 ==========
# ========== 600 ===== ===== test accuracy is  0.906 ==========
# ========== 620 ===== ===== test accuracy is  0.902 ==========
# ========== 640 ===== ===== test accuracy is  0.902 ==========
# ========== 660 ===== ===== test accuracy is  0.91 ==========
# ========== 680 ===== ===== test accuracy is  0.922 ==========
# ========== 700 ===== ===== test accuracy is  0.93 ==========
# ========== 720 ===== ===== test accuracy is  0.922 ==========
# ========== 740 ===== ===== test accuracy is  0.932 ==========
# ========== 760 ===== ===== test accuracy is  0.926 ==========
# ========== 780 ===== ===== test accuracy is  0.918 ==========
# ========== 800 ===== ===== test accuracy is  0.924 ==========
# ========== 820 ===== ===== test accuracy is  0.93 ==========
# ========== 840 ===== ===== test accuracy is  0.928 ==========
# ========== 860 ===== ===== test accuracy is  0.914 ==========
# ========== 880 ===== ===== test accuracy is  0.938 ==========
# ========== 900 ===== ===== test accuracy is  0.93 ==========
# ========== 920 ===== ===== test accuracy is  0.936 ==========
# ========== 940 ===== ===== test accuracy is  0.942 ==========
# ========== 960 ===== ===== test accuracy is  0.946 ==========
# ========== 980 ===== ===== test accuracy is  0.942 ==========
# ========== 1000 ===== ===== test accuracy is  0.942 ==========
# ========== 1020 ===== ===== test accuracy is  0.938 ==========
# ========== 1040 ===== ===== test accuracy is  0.932 ==========
# ========== 1060 ===== ===== test accuracy is  0.944 ==========
# ========== 1080 ===== ===== test accuracy is  0.94 ==========
# ========== 1100 ===== ===== test accuracy is  0.94 ==========
# ========== 1120 ===== ===== test accuracy is  0.944 ==========
# ========== 1140 ===== ===== test accuracy is  0.936 ==========
# ========== 1160 ===== ===== test accuracy is  0.94 ==========
# ========== 1180 ===== ===== test accuracy is  0.95 ==========
# ========== 20 ===== ===== test accuracy is  0.944 ==========
# ========== 40 ===== ===== test accuracy is  0.942 ==========
# ========== 60 ===== ===== test accuracy is  0.952 ==========
# ========== 80 ===== ===== test accuracy is  0.946 ==========
# ========== 100 ===== ===== test accuracy is  0.948 ==========
# ========== 120 ===== ===== test accuracy is  0.946 ==========
# ========== 140 ===== ===== test accuracy is  0.958 ==========
# ========== 160 ===== ===== test accuracy is  0.95 ==========
# ========== 180 ===== ===== test accuracy is  0.942 ==========
# ========== 200 ===== ===== test accuracy is  0.96 ==========
# ========== 220 ===== ===== test accuracy is  0.96 ==========
# ========== 240 ===== ===== test accuracy is  0.956 ==========
# ========== 260 ===== ===== test accuracy is  0.956 ==========
# ========== 280 ===== ===== test accuracy is  0.958 ==========
# ========== 300 ===== ===== test accuracy is  0.95 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.972 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.944 ==========
# ========== 400 ===== ===== test accuracy is  0.958 ==========
# ========== 420 ===== ===== test accuracy is  0.944 ==========
# ========== 440 ===== ===== test accuracy is  0.958 ==========
# ========== 460 ===== ===== test accuracy is  0.966 ==========
# ========== 480 ===== ===== test accuracy is  0.952 ==========
# ========== 500 ===== ===== test accuracy is  0.952 ==========
# ========== 520 ===== ===== test accuracy is  0.954 ==========
# ========== 540 ===== ===== test accuracy is  0.958 ==========
# ========== 560 ===== ===== test accuracy is  0.956 ==========
# ========== 580 ===== ===== test accuracy is  0.96 ==========
# ========== 600 ===== ===== test accuracy is  0.954 ==========
# ========== 620 ===== ===== test accuracy is  0.948 ==========
# ========== 640 ===== ===== test accuracy is  0.964 ==========
# ========== 660 ===== ===== test accuracy is  0.962 ==========
# ========== 680 ===== ===== test accuracy is  0.958 ==========
# ========== 700 ===== ===== test accuracy is  0.956 ==========
# ========== 720 ===== ===== test accuracy is  0.956 ==========
# ========== 740 ===== ===== test accuracy is  0.956 ==========
# ========== 760 ===== ===== test accuracy is  0.962 ==========
# ========== 780 ===== ===== test accuracy is  0.962 ==========
# ========== 800 ===== ===== test accuracy is  0.966 ==========
# ========== 820 ===== ===== test accuracy is  0.964 ==========
# ========== 840 ===== ===== test accuracy is  0.966 ==========
# ========== 860 ===== ===== test accuracy is  0.968 ==========
# ========== 880 ===== ===== test accuracy is  0.962 ==========
# ========== 900 ===== ===== test accuracy is  0.954 ==========
# ========== 920 ===== ===== test accuracy is  0.96 ==========
# ========== 940 ===== ===== test accuracy is  0.962 ==========
# ========== 960 ===== ===== test accuracy is  0.96 ==========
# ========== 980 ===== ===== test accuracy is  0.966 ==========
# ========== 1000 ===== ===== test accuracy is  0.974 ==========
# ========== 1020 ===== ===== test accuracy is  0.966 ==========
# ========== 1040 ===== ===== test accuracy is  0.966 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.952 ==========
# ========== 1100 ===== ===== test accuracy is  0.968 ==========
# ========== 1120 ===== ===== test accuracy is  0.968 ==========
# ========== 1140 ===== ===== test accuracy is  0.964 ==========
# ========== 1160 ===== ===== test accuracy is  0.972 ==========
# ========== 1180 ===== ===== test accuracy is  0.97 ==========
# ========== 20 ===== ===== test accuracy is  0.964 ==========
# ========== 40 ===== ===== test accuracy is  0.968 ==========
# ========== 60 ===== ===== test accuracy is  0.97 ==========
# ========== 80 ===== ===== test accuracy is  0.972 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.964 ==========
# ========== 140 ===== ===== test accuracy is  0.968 ==========
# ========== 160 ===== ===== test accuracy is  0.968 ==========
# ========== 180 ===== ===== test accuracy is  0.97 ==========
# ========== 200 ===== ===== test accuracy is  0.968 ==========
# ========== 220 ===== ===== test accuracy is  0.974 ==========
# ========== 240 ===== ===== test accuracy is  0.964 ==========
# ========== 260 ===== ===== test accuracy is  0.976 ==========
# ========== 280 ===== ===== test accuracy is  0.968 ==========
# ========== 300 ===== ===== test accuracy is  0.962 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.974 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.962 ==========
# ========== 400 ===== ===== test accuracy is  0.968 ==========
# ========== 420 ===== ===== test accuracy is  0.968 ==========
# ========== 440 ===== ===== test accuracy is  0.972 ==========
# ========== 460 ===== ===== test accuracy is  0.978 ==========
# ========== 480 ===== ===== test accuracy is  0.974 ==========
# ========== 500 ===== ===== test accuracy is  0.972 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.976 ==========
# ========== 560 ===== ===== test accuracy is  0.974 ==========
# ========== 580 ===== ===== test accuracy is  0.97 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.976 ==========
# ========== 640 ===== ===== test accuracy is  0.966 ==========
# ========== 660 ===== ===== test accuracy is  0.978 ==========
# ========== 680 ===== ===== test accuracy is  0.98 ==========
# ========== 700 ===== ===== test accuracy is  0.968 ==========
# ========== 720 ===== ===== test accuracy is  0.978 ==========
# ========== 740 ===== ===== test accuracy is  0.97 ==========
# ========== 760 ===== ===== test accuracy is  0.97 ==========
# ========== 780 ===== ===== test accuracy is  0.966 ==========
# ========== 800 ===== ===== test accuracy is  0.97 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.968 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.964 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.976 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.972 ==========
# ========== 1000 ===== ===== test accuracy is  0.966 ==========
# ========== 1020 ===== ===== test accuracy is  0.97 ==========
# ========== 1040 ===== ===== test accuracy is  0.974 ==========
# ========== 1060 ===== ===== test accuracy is  0.978 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.972 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.966 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.974 ==========
